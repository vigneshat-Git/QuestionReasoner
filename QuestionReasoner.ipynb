# %%
# ✅ Step 1: Install Libraries (run in Colab)
# !pip install transformers datasets -q

# ✅ Step 2: Import Required Libraries
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
import torch

# ✅ Step 3: Load Model and Tokenizer (FLAN-T5)
model_name = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# ✅ Step 4: Build a Chain-of-Thought Generation Function
def generate_reasoning_answer(question):
    prompt = f"Answer the question step-by-step: {question}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True)
    outputs = model.generate(**inputs, max_length=256, temperature=0.7, top_p=0.95)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# ✅ Step 5: Try Example Inputs
questions = input()

print("\n🟨 Question: questions")
print("🟩 Answer with Reasoning: generate_reasoning_answer(questions)")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 🟨 Question: What is the sum of the first 10 even numbers?
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 🟩 Answer with Reasoning: The first 10 even numbers are 10 * 10 = 100. The sum of the first 10 even numbers is 100 * 10 = 900. The sum of the first 10 even numbers is 900 + 900 = 900. The final answer: 900.
#
# 🟨 Question: Why does the moon cause tides on Earth?
# ...

# %%
# ✅ Step 5: Try Example Inputs
questions = input()

print("\n🟨 Question: ",)
print("🟩 Answer with Reasoning:", generate_reasoning_answer(questions))
# Out:
# what is 1+1?
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 🟨 Question:  what is 1+1?
# 🟩 Answer with Reasoning: 1+1 is a digit that is a combination of 1 and 1.

# %%
# ✅ Step 5: Try Example Inputs
questions = input()

print("\n🟨 Question: ",)
print("🟩 Answer with Reasoning:", generate_reasoning_answer(questions))
# Out:
# what is the sum of all prime numbers between 1 - 100?
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 🟨 Question:
# 🟩 Answer with Reasoning: The sum of all prime numbers between 1 and 100 is 100. The sum of all prime numbers between 1 and 100 is 100. The final answer: 100.
